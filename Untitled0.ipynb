# %%
# Description: This program uses an AI RNN called LSTM to predict the closing price of Nvidia using the past 60 day stock price.

# %%
#install yahoo finance API
# !pip install yfinance --quiet

# %%
# Import the libraries
import math
import yfinance as yf
import pandas as pd
import yfinance as yf
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, LSTM
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')

# %%
# Download Nvidia stock data
nvidia = yf.download(
    tickers='NVDA',
    start='2017-01-01',
    end='2025-08-27',
    progress=False
)

# Output the data
nvidia
# Out:
# /tmp/ipython-input-1419673435.py:2: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   nvidia = yf.download(
# Price            Close        High         Low        Open      Volume
# Ticker            NVDA        NVDA        NVDA        NVDA        NVDA
# Date
# 2017-01-03    2.512489    2.619875    2.447712    2.571354  1501996000
# 2017-01-04    2.571107    2.598446    2.500666    2.546724  1199220000
# 2017-01-05    2.505839    2.606329    2.488844    2.574556   984296000
# 2017-01-06    2.539335    2.567659    2.492538    2.533177   822856000
# 2017-01-09    2.642288    2.660021    2.549187    2.549187   916248000
# ...                ...         ...         ...         ...         ...
# 2025-08-20  175.399994  176.000000  168.800003  175.169998   215142700
# 2025-08-21  174.979996  176.899994  173.809998  174.850006   140040900
# 2025-08-22  177.990005  178.589996  171.199997  172.610001   172789400
# ...

# %%
# Get the number of rows and columns of the data set
nvidia.shape
# Out:
# (2174, 5)

# %%
# Plot the closing price history of Nvidia from 2017-01-01 to 2025-08-27
plt.figure(figsize=(16,8))
plt.title('Close Price History')
plt.plot(nvidia['Close'])
plt.xlabel('Date', fontsize = 18)
plt.ylabel('Close Price USD ($)', fontsize = 18)
plt.show()

# %%
nvidia.columns = nvidia.columns.droplevel(1)
data = nvidia.filter(['Close'])
dataset = data.values
training_data_len = math.ceil(len(dataset) * 0.8)
training_data_len
# Out:
# 1740

# %%
scaler = MinMaxScaler(feature_range=(0,1))
scaled_data = scaler.fit_transform(dataset)
scaled_data
# Out:
# array([[8.71760429e-04],
#        [1.19596884e-03],
#        [8.34983298e-04],
#        ...,
#        [9.71405689e-01],
#        [9.81471731e-01],
#        [9.92312169e-01]])

# %%
train_data = scaled_data[0:training_data_len, :]
x_train = []
y_train = []

for i in range (60, len(train_data)):
  x_train.append(train_data[i-60:i, 0])
  y_train.append(train_data[i,0])

# %%
x_train = np.array(x_train)
y_train = np.array(y_train)

x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))
x_train.shape
# Out:
# (1680, 60, 1)

# %%
model = Sequential()
model.add(LSTM(50, return_sequences=True, input_shape=(x_train.shape[1], 1)))
model.add(LSTM(50, return_sequences=False))
model.add(Dense(25))
model.add(Dense(1))

# %%
model.compile(optimizer='adam', loss = 'mean_squared_error')

# %%
model.fit(x_train,y_train, batch_size=1, epochs=1)
# Out:
# 1680/1680 ━━━━━━━━━━━━━━━━━━━━ 51s 29ms/step - loss: 3.3188e-04

# %%
test_data = scaled_data[training_data_len - 60:, :]
x_test = []
y_test = dataset[training_data_len:, :]
for i in range(60, len(test_data)):
  x_test.append(test_data[i-60:i, 0])

# %%
x_test = np.array(x_test)
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))

# %%
predictions = model.predict(x_test)
predictions = scaler.inverse_transform(predictions)
# Out:
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step

# %%
rmse=np.sqrt(np.mean(((predictions- y_test)**2)))
rmse
# Out:
# np.float64(10.632956867921898)

# %%
train = data[:training_data_len]
valid = data[training_data_len:]
valid['Predictions'] = predictions

plt.figure(figsize=(16,8))
plt.title('Model')
plt.xlabel('Date', fontsize = 18)
plt.ylabel('Close Price USD ($)', fontsize = 18)
plt.plot(train['Close'])
plt.plot(valid[['Close', 'Predictions']])
plt.legend(['Train', 'Val', 'Predictions'], loc = 'lower right')
plt.show()
# Out:
# /tmp/ipython-input-1615796454.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid['Predictions'] = predictions
